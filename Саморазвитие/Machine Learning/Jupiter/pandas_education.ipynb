# %% [markdown]
# В этом блокноте будет обучение pandas

# %% [markdown]
# https://drive.google.com/file/d/1wZUhq6A0aMcAD5Z0X8oOn6YYrQxw1bGN/view?usp=sharing
# https://www.kaggle.com/datasets/arashnic/hr-analytics-job-change-of-data-scientists

# %% [markdown]
# Загрузка данных

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("arashnic/hr-analytics-job-change-of-data-scientists")

print("Path to dataset files:", path)
# Out:
# Path to dataset files: /Users/yapimiu/.cache/kagglehub/datasets/arashnic/hr-analytics-job-change-of-data-scientists/versions/1

# %% [markdown]
# Чтение данных

# %%
import pandas as pd

# %%
df = pd.read_csv('/Users/yapimiu/.cache/kagglehub/datasets/arashnic/hr-analytics-job-change-of-data-scientists/versions/1/aug_train.csv')

# %% [markdown]
# Основные операции с датафреймом

# %%
# Показ строк датафрейма
df
# Out:
#        enrollee_id      city  city_development_index gender  \
# 0             8949  city_103                   0.920   Male
# 1            29725   city_40                   0.776   Male
# 2            11561   city_21                   0.624    NaN
# 3            33241  city_115                   0.789    NaN
# 4              666  city_162                   0.767   Male
# ...            ...       ...                     ...    ...
# 19153         7386  city_173                   0.878   Male
# 19154        31398  city_103                   0.920   Male
# 19155        24576  city_103                   0.920   Male
# 19156         5756   city_65                   0.802   Male
# 19157        23834   city_67                   0.855    NaN
#
#            relevent_experience enrolled_university education_level  \
# 0      Has relevent experience       no_enrollment        Graduate
# 1       No relevent experience       no_enrollment        Graduate
# ...

# %%
# Показ столбца в виде строки (siries)
# Поддреживает только один столбец
df['city']
# Out:
# 0        city_103
# 1         city_40
# 2         city_21
# 3        city_115
# 4        city_162
#            ...
# 19153    city_173
# 19154    city_103
# 19155    city_103
# 19156     city_65
# 19157     city_67
# Name: city, Length: 19158, dtype: object

# %%
# Показ столбца в виде таблицы
# Поддерживает много столбцов
df[['city']]
# Out:
#            city
# 0      city_103
# 1       city_40
# 2       city_21
# 3      city_115
# 4      city_162
# ...         ...
# 19153  city_173
# 19154  city_103
# 19155  city_103
# 19156   city_65
# 19157   city_67
#
# [19158 rows x 1 columns]

# %%
# Удалить столбец
# axis - индекс столбца
df = df.drop('city', axis=1)

# %%
df = pd.read_csv('/Users/yapimiu/.cache/kagglehub/datasets/arashnic/hr-analytics-job-change-of-data-scientists/versions/1/aug_train.csv')

# %%
# Выбор только нужных столбцов
df[['city', 'city_development_index']]
# Out:
#            city  city_development_index
# 0      city_103                   0.920
# 1       city_40                   0.776
# 2       city_21                   0.624
# 3      city_115                   0.789
# 4      city_162                   0.767
# ...         ...                     ...
# 19153  city_173                   0.878
# 19154  city_103                   0.920
# 19155  city_103                   0.920
# 19156   city_65                   0.802
# 19157   city_67                   0.855
#
# [19158 rows x 2 columns]

# %% [markdown]
# Добавление столбцов

# %%
df['new_coll'] = 1
df['new_coll2'] = df['city_development_index'] / 3
df
# Out:
#        enrollee_id      city  city_development_index gender  \
# 0             8949  city_103                   0.920   Male
# 1            29725   city_40                   0.776   Male
# 2            11561   city_21                   0.624    NaN
# 3            33241  city_115                   0.789    NaN
# 4              666  city_162                   0.767   Male
# ...            ...       ...                     ...    ...
# 19153         7386  city_173                   0.878   Male
# 19154        31398  city_103                   0.920   Male
# 19155        24576  city_103                   0.920   Male
# 19156         5756   city_65                   0.802   Male
# 19157        23834   city_67                   0.855    NaN
#
#            relevent_experience enrolled_university education_level  \
# 0      Has relevent experience       no_enrollment        Graduate
# 1       No relevent experience       no_enrollment        Graduate
# ...

# %% [markdown]
# Фильтрация

# %%
df[df['city'] == 'city_40']
# Out:
#        enrollee_id     city  city_development_index gender  \
# 1            29725  city_40                   0.776   Male
# 23            7041  city_40                   0.776   Male
# 363          28229  city_40                   0.776   Male
# 461          18620  city_40                   0.776   Male
# 827           1783  city_40                   0.776   Male
# ...            ...      ...                     ...    ...
# 18032          982  city_40                   0.776    NaN
# 18061        11208  city_40                   0.776   Male
# 18191          157  city_40                   0.776   Male
# 18650        26348  city_40                   0.776   Male
# 19142        13750  city_40                   0.776   Male
#
#            relevent_experience enrolled_university education_level  \
# 1       No relevent experience       no_enrollment        Graduate
# 23     Has relevent experience       no_enrollment        Graduate
# ...

# %%
df.query('city == "city_40"')
# Out:
#        enrollee_id     city  city_development_index gender  \
# 1            29725  city_40                   0.776   Male
# 23            7041  city_40                   0.776   Male
# 363          28229  city_40                   0.776   Male
# 461          18620  city_40                   0.776   Male
# 827           1783  city_40                   0.776   Male
# ...            ...      ...                     ...    ...
# 18032          982  city_40                   0.776    NaN
# 18061        11208  city_40                   0.776   Male
# 18191          157  city_40                   0.776   Male
# 18650        26348  city_40                   0.776   Male
# 19142        13750  city_40                   0.776   Male
#
#            relevent_experience enrolled_university education_level  \
# 1       No relevent experience       no_enrollment        Graduate
# 23     Has relevent experience       no_enrollment        Graduate
# ...

# %%
df[(df['city'] == 'city_40') & (df['gender'] == 'Male')]
# Out:
#        enrollee_id     city  city_development_index gender  \
# 1            29725  city_40                   0.776   Male
# 23            7041  city_40                   0.776   Male
# 363          28229  city_40                   0.776   Male
# 461          18620  city_40                   0.776   Male
# 827           1783  city_40                   0.776   Male
# 998          29671  city_40                   0.776   Male
# 2916         21646  city_40                   0.776   Male
# 3636         10085  city_40                   0.776   Male
# 4251          2603  city_40                   0.776   Male
# 4346          4051  city_40                   0.776   Male
# 4526         11840  city_40                   0.776   Male
# 4588          7010  city_40                   0.776   Male
# 5156          7556  city_40                   0.776   Male
# 6330          5389  city_40                   0.776   Male
# 6483           484  city_40                   0.776   Male
# ...

# %% [markdown]
# # Пропуски (например, когда в столбце есть неподходящие данные (в столбце male "NaN"))

# %%
# Колчиство процентов с неопределенными данными
# sort_values - сортировка
# ascending - порядок сортировки (False - убывание, True - возростание (значение по умолчанию))
df.isna().mean().sort_values(ascending=False)
# Out:
# company_type              0.320493
# company_size              0.309949
# gender                    0.235306
# major_discipline          0.146832
# education_level           0.024011
# last_new_job              0.022080
# enrolled_university       0.020148
# experience                0.003393
# enrollee_id               0.000000
# city                      0.000000
# city_development_index    0.000000
# relevent_experience       0.000000
# training_hours            0.000000
# target                    0.000000
# new_coll                  0.000000
# new_coll2                 0.000000
# dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19158 entries, 0 to 19157
# Data columns (total 16 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   enrollee_id             19158 non-null  int64
#  1   city                    19158 non-null  object
#  2   city_development_index  19158 non-null  float64
#  3   gender                  14650 non-null  object
#  4   relevent_experience     19158 non-null  object
#  5   enrolled_university     18772 non-null  object
#  6   education_level         18698 non-null  object
#  7   major_discipline        16345 non-null  object
#  8   experience              19093 non-null  object
#  9   company_size            13220 non-null  object
#  10  company_type            13018 non-null  object
#  11  last_new_job            18735 non-null  object
#  12  training_hours          19158 non-null  int64
#  13  target                  19158 non-null  float64
# ...

# %%
df.dtypes
# Out:
# enrollee_id                 int64
# city                       object
# city_development_index    float64
# gender                     object
# relevent_experience        object
# enrolled_university        object
# education_level            object
# major_discipline           object
# experience                 object
# company_size               object
# company_type               object
# last_new_job               object
# training_hours              int64
# target                    float64
# new_coll                    int64
# new_coll2                 float64
# dtype: object

# %%
df
# Out:
#        enrollee_id      city  city_development_index gender  \
# 0             8949  city_103                   0.920   Male
# 1            29725   city_40                   0.776   Male
# 2            11561   city_21                   0.624    NaN
# 3            33241  city_115                   0.789    NaN
# 4              666  city_162                   0.767   Male
# ...            ...       ...                     ...    ...
# 19153         7386  city_173                   0.878   Male
# 19154        31398  city_103                   0.920   Male
# 19155        24576  city_103                   0.920   Male
# 19156         5756   city_65                   0.802   Male
# 19157        23834   city_67                   0.855    NaN
#
#            relevent_experience enrolled_university education_level  \
# 0      Has relevent experience       no_enrollment        Graduate
# 1       No relevent experience       no_enrollment        Graduate
# ...

# %%
import matplotlib.pyplot as plt
plt.style.use('dark_background')

# %%
df['city_development_index'].hist()

# В данной случае на гистограмме мы видим, что больше всего дата саентистов живет в развитых городах
# (с индексом < 0.9)
# Out:
# <Axes: >

# %%
# Количество данных в столбце
# dropna - не учитывать NaN

df['gender'].value_counts(dropna=False)
# Out:
# gender
# Male      13221
# NaN        4508
# Female     1238
# Other       191
# Name: count, dtype: int64

# %% [markdown]
# # Фильтрация по квантилю

# %%
q1 = df['city_development_index'].quantile(0.05)
q2 = df['city_development_index'].quantile(0.95)

# %%
df[df['city_development_index'].between(q1,q2)]['city_development_index'].hist()
# Out:
# <Axes: >

# %% [markdown]
# # Сводники (сводные таблицы)

# %% [markdown]
# ## Сводники для категориальных переменных

# %%
df['target'].mean()
# Out:
# np.float64(0.24934753105752167)

# %%
t = df.groupby('gender', dropna=False)['target'].agg(['count', 'mean'])

# %%
if t['count'].sum() == len(df):
    print("True")
else:
    print("False")
# Out:
# True

# %%
t.plot(kind='bar')
# Out:
# <Axes: xlabel='gender'>

# %% [markdown]
# ## Сводники для непрерывных переменных

# %%
df['city_development_index_group'] = pd.cut(df['city_development_index'], 5)

# %%
df.groupby('city_development_index_group', dropna=False)['target'].agg(['count', 'mean'])
# Out:
# /var/folders/y_/7smt58yn1_j1z08l67wqfxph0000gn/T/ipykernel_4939/3835047553.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby('city_development_index_group', dropna=False)['target'].agg(['count', 'mean'])
#                               count      mean
# city_development_index_group
# (0.447, 0.548]                  178  0.578652
# (0.548, 0.648]                 3297  0.582651
# (0.648, 0.749]                 1529  0.273381
# (0.749, 0.849]                 1949  0.194459
# (0.849, 0.949]                12205  0.160262

# %%
df['city_development_index_group_q'] = pd.qcut(df['city_development_index'], 5, duplicates='drop')

# %%
p = df.groupby('city_development_index_group_q', dropna=False)['target'].agg(['count', 'mean'])
# Out:
# /var/folders/y_/7smt58yn1_j1z08l67wqfxph0000gn/T/ipykernel_4939/3843178005.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   p = df.groupby('city_development_index_group_q', dropna=False)['target'].agg(['count', 'mean'])

# %%
p['count'].sum()
# Out:
# np.int64(19158)

# %%
p['mean'].plot()
# Out:
# <Axes: xlabel='city_development_index_group_q'>

# %% [markdown]
# ## Кастомные интервалы

# %%
df['city_development_index_group_custom'] = pd.cut(df['city_development_index'],
                                                    [-float('inf'),0, 0.1, 0.2, 0.5, float('inf')])

# %%
df.groupby('city_development_index_group_custom', dropna=False)['target'].agg(['count', 'mean'])
# Out:
# /var/folders/y_/7smt58yn1_j1z08l67wqfxph0000gn/T/ipykernel_4939/2315422812.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby('city_development_index_group_custom', dropna=False)['target'].agg(['count', 'mean'])
#                                      count      mean
# city_development_index_group_custom
# (-inf, 0.0]                              0       NaN
# (0.0, 0.1]                               0       NaN
# (0.1, 0.2]                               0       NaN
# (0.2, 0.5]                              63  0.587302
# (0.5, inf]                           19095  0.248233

# %%
def education_group(x):
    if x in ['High School', 'Primary School']:
        return 'School'
    if x in ['Masters', 'Phd']:
        return 'Masters and Phd'
    return x

# %%
df['new_education_level'] = df['education_level'].apply(education_group)

# %%
df.groupby('new_education_level', dropna=False)['target'].agg(['count', 'mean'])
# Out:
#                      count      mean
# new_education_level
# Graduate             11598  0.279790
# Masters and Phd       4775  0.207958
# School                2325  0.187097
# NaN                    460  0.226087

# %%
def new_traning_hours(row):
